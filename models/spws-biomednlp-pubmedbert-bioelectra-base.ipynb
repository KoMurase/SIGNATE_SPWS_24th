# %%
# !pip install -q transformers
# Out:
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %% [markdown]
# reference :
#
# https://colab.research.google.com/drive/19loLGUDjxGKy4ulZJ1m3hALq2ozNyEGe#scrollTo=oJFsRo_vGDYU
#
# https://www.kaggle.com/piantic/pytorch-tpu

# %%
# for TPU
#!curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py
#!python pytorch-xla-env-setup.py --apt-packages libomp5 libopenblas-dev

# %%
import os 
import sys

import math
import random
import time
import warnings

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import transformers as T
from sklearn.metrics import fbeta_score
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import DataLoader, Dataset
from tqdm.notebook import tqdm

import seaborn as sns

# %%
warnings.filterwarnings("ignore")

# %%
'''# imports the torch_xla package
import torch_xla
import torch_xla.core.xla_model as xm

device = xm.xla_device()
torch.set_default_tensor_type('torch.FloatTensor')
'''
# Out:
# "# imports the torch_xla package\nimport torch_xla\nimport torch_xla.core.xla_model as xm\n\ndevice = xm.xla_device()\ntorch.set_default_tensor_type('torch.FloatTensor')\n"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
DATA_DIR = "../input/signate-spws-2/"
OUTPUT_DIR = "./"

#../input/signate-spws-2/train.csv

# %%
DEBUG = False

if DEBUG:
  train = pd.read_csv(DATA_DIR + "train.csv").sample(20).reset_index(drop=True)
  test = pd.read_csv(DATA_DIR + "test.csv").sample(20).reset_index(drop=True)
  sub = pd.read_csv(DATA_DIR + "sample_submit.csv", header=None).sample(20).reset_index(drop=True)
  sub.columns = ["id", "judgement"]
else:
  train = pd.read_csv(DATA_DIR + "train.csv")
  test = pd.read_csv(DATA_DIR + "test.csv")
  sub = pd.read_csv(DATA_DIR + "sample_submit.csv", header=None)
  sub.columns = ["id", "judgement"]

# %%
train['text'] = train['title']+ " " + train["abstract"].fillna('NaN')
train['text_len'] = train['text'].apply(lambda x: len(x.split(' ')))

# %%
#データの訂正
train.loc[train['id'] == 2488, 'judgement'] = 0
train.loc[train['id'] == 7708, 'judgement'] = 0

# %%
class config:
  if DEBUG:
    border = len(train[train["judgement"] == 1]) / len(train["judgement"])
    seed = 89
    NUM_SPLITS = 5
    MAX_LEN = 400
    #MODEL_NAME = "bert-base-uncased"
    MODEL_NAME = "allenai/scibert_scivocab_uncased"
    TRAIN_BATCH_SIZE = 16
    VALID_BATCH_SIZE = 16
    
    EPOCH = 3

  else:
    FILENAME = 'bioelectra-base'

    border = len(train[train["judgement"] == 1]) / len(train["judgement"])
    seed = 89
    NUM_SPLITS = 5
    MAX_LEN = 400
    #MODEL_NAME = "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext"
    MODEL_NAME = "kamalkraj/bioelectra-base-discriminator-pubmed"
    TRAIN_BATCH_SIZE = 16
    VALID_BATCH_SIZE = 16
    
    EPOCH = 3

# %%
def init_logger(log_file=OUTPUT_DIR + f"{config.FILENAME}_train.log"):
    from logging import INFO, FileHandler, Formatter, StreamHandler, getLogger

    logger = getLogger(__name__)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    handler2 = FileHandler(filename=log_file)
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    logger.addHandler(handler2)
    return logger

LOGGER = init_logger()

# %%
def seed_torch(seed=42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

seed = config.seed
seed_torch(seed)

# %%
from scipy.optimize import minimize, minimize_scalar
def optimize_threshold(y_true, y_pred):
    """fbeta score計算時のthresholdを最適化"""
    def opt_(x): 
        return -fbeta_score(y_true, y_pred >= x, beta=7)
    #result = minimize(opt_, x0=np.array([0.5]), method='Nelder-Mead')
    result = minimize_scalar(opt_, bounds=(0, 0.5), method='bounded') 

    best_threshold = result['x'].item()
    return best_threshold

# %%
def get_train_data(train):

    # 交差検証 用の番号を振ります。
    Fold = StratifiedKFold(n_splits=config.NUM_SPLITS, shuffle=True, random_state=seed)
    for n, (train_index, val_index) in enumerate(Fold.split(train, train["judgement"])):
        train.loc[val_index, "fold"] = int(n)
    train["fold"] = train["fold"].astype(np.uint8)

    return train

# %%
train = get_train_data(train)

# %%
class BaseDataset(Dataset):
    def __init__(self, df, model_name, include_labels=True):
        tokenizer = T.ElectraTokenizer.from_pretrained(model_name)

        self.df = df
        self.include_labels = include_labels

        #self.title = df["title"].tolist()
        df["text"] = df["title"]+" "+df["abstract"].fillna('NaN')
        #self.title = df["text"].tolist()
        self.text = df["text"].tolist()

        self.encoded = tokenizer.batch_encode_plus(
            self.text,
            padding = 'max_length',            
            max_length = config.MAX_LEN,
            truncation = True,
            return_attention_mask=True
        )
        
        if self.include_labels:
            self.labels = df["judgement"].values

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        input_ids = torch.tensor(self.encoded['input_ids'][idx])
        attention_mask = torch.tensor(self.encoded['attention_mask'][idx])

        if self.include_labels:
            label = torch.tensor(self.labels[idx]).float()
            return input_ids, attention_mask, label

        return input_ids, attention_mask

# %%
class BaseModel(nn.Module):
    def __init__(self, model_name):
        super().__init__()

        self.model = T.ElectraForSequenceClassification.from_pretrained(model_name, num_labels=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, input_ids, attention_mask):
        out = self.model(input_ids=input_ids, attention_mask=attention_mask)
        out = self.sigmoid(out.logits).squeeze()

        return out

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return "%dm %ds" % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return "%s (remain %s)" % (asMinutes(s), asMinutes(rs))

# %%
def train_fn(train_loader, model, criterion, optimizer, epoch, device):
    start = end = time.time()
    losses = AverageMeter()

    # switch to train mode
    model.train()

    for step, (input_ids, attention_mask, labels) in enumerate(train_loader):
        optimizer.zero_grad()

        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)

        y_preds = model(input_ids, attention_mask)

        loss = criterion(y_preds, labels)

        # record loss
        losses.update(loss.item(), batch_size)
        loss.backward()

        optimizer.step()
        #xm.optimizer_step(optimizer, barrier=True)

        if step % 100 == 0 or step == (len(train_loader) - 1):
            print(
                f"Epoch: [{epoch + 1}][{step}/{len(train_loader)}] "
                f"Elapsed {timeSince(start, float(step + 1) / len(train_loader)):s} "
                f"Loss: {losses.avg:.4f} "
            )

    return losses.avg

# %%
def valid_fn(valid_loader, model, criterion, device):
    start = end = time.time()
    losses = AverageMeter()

    # switch to evaluation mode
    model.eval()
    preds = []

    for step, (input_ids, attention_mask, labels) in enumerate(valid_loader):
        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)

        # compute loss
        with torch.no_grad():
            y_preds = model(input_ids, attention_mask)

        loss = criterion(y_preds, labels)
        losses.update(loss.item(), batch_size)

        # record score
        preds.append(y_preds.to("cpu").numpy())

        if step % 100 == 0 or step == (len(valid_loader) - 1):
            print(
                f"EVAL: [{step}/{len(valid_loader)}] "
                f"Elapsed {timeSince(start, float(step + 1) / len(valid_loader)):s} "
                f"Loss: {losses.avg:.4f} "
            )

    predictions = np.concatenate(preds)
    return losses.avg, predictions

# %%
def inference():
    predictions = []

    test_dataset = BaseDataset(test, config.MODEL_NAME, include_labels=False)
    test_loader = DataLoader(
        test_dataset, batch_size=16, shuffle=False, num_workers=4, pin_memory=True
    )

    for fold in range(5):
        LOGGER.info(f"========== model: {config.FILENAME} fold: {fold} inference ==========")
        model = BaseModel(config.MODEL_NAME)
        model.to(device)
        model.load_state_dict(torch.load(OUTPUT_DIR + f"{config.FILENAME}_fold{fold}_best.pth")["model"])
        model.eval()
        preds = []
        for i, (input_ids, attention_mask) in tqdm(enumerate(test_loader), total=len(test_loader)):
            input_ids = input_ids.to(device)
            attention_mask = attention_mask.to(device)
            with torch.no_grad():
                y_preds = model(input_ids, attention_mask)
            preds.append(y_preds.to("cpu").numpy())
        preds = np.concatenate(preds)
        predictions.append(preds)
    predictions = np.mean(predictions, axis=0)

    return predictions

# %%
def train_loop(train, fold):

    LOGGER.info(f"========== fold: {fold} training ==========")

    # ====================================================
    # Data Loader
    # ====================================================
    trn_idx = train[train["fold"] != fold].index
    val_idx = train[train["fold"] == fold].index

    train_folds = train.loc[trn_idx].reset_index(drop=True)
    valid_folds = train.loc[val_idx].reset_index(drop=True)

    train_dataset = BaseDataset(train_folds, config.MODEL_NAME)
    valid_dataset = BaseDataset(valid_folds, config.MODEL_NAME)

    train_loader = DataLoader(
        train_dataset,
        batch_size=config.TRAIN_BATCH_SIZE,
        shuffle=True,
        num_workers=4,
        pin_memory=True,
        drop_last=True,
    )
    valid_loader = DataLoader(
        valid_dataset,
        batch_size=config.VALID_BATCH_SIZE,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
        drop_last=False,
    )

    # ====================================================
    # Model
    # ====================================================
    model = BaseModel(config.MODEL_NAME)
    model.to(device)

    optimizer = T.AdamW(model.parameters(), lr=2e-5)

    criterion = nn.BCELoss()

    # ====================================================
    # Loop
    # ====================================================
    best_score = -1
    best_loss = np.inf

    for epoch in range(config.EPOCH):
        start_time = time.time()
        
        # train
        avg_loss = train_fn(train_loader, model, criterion, optimizer, epoch, device)

        # eval
        avg_val_loss, preds = valid_fn(valid_loader, model, criterion, device)
        valid_labels = valid_folds["judgement"].values

        # scoring
        score = fbeta_score(valid_labels, np.where(preds < config.border, 0, 1), beta=7.0)

        elapsed = time.time() - start_time
        LOGGER.info(
            f"Epoch {epoch+1} - avg_train_loss: {avg_loss:.4f}  avg_val_loss: {avg_val_loss:.4f}  time: {elapsed:.0f}s"
        )
        LOGGER.info(f"Epoch {epoch+1} - Score: {score}")

        if score > best_score:
            best_score = score
            LOGGER.info(f"Epoch {epoch+1} - Save Best Score: {best_score:.4f} Model")
            torch.save(
                {"model": model.state_dict(), "preds": preds}, OUTPUT_DIR + f"{config.FILENAME}_fold{fold}_best.pth"
            )

    check_point = torch.load(OUTPUT_DIR + f"{config.FILENAME}_fold{fold}_best.pth")

    valid_folds["preds"] = check_point["preds"]

    return valid_folds

# %%
def get_result(result_df):
    preds = result_df["preds"].values
    labels = result_df["judgement"].values
    score = fbeta_score(labels, np.where(preds < config.border, 0, 1), beta=7.0)
    LOGGER.info(f"Score: {score:<.5f}")

    best_threshold = optimize_threshold(labels, preds)
    LOGGER.info(f"Best threshold : {best_threshold:<.5f}")
    score = fbeta_score(labels, np.where(preds < best_threshold, 0, 1), beta=7.0)
    LOGGER.info(f"After optimizing score: {score:<.5f}")

    return best_threshold

# %%
def main():
    # Training
    oof_df = pd.DataFrame()
    threshold = []
    for fold in range(5):
        _oof_df = train_loop(train, fold)
        oof_df = pd.concat([oof_df, _oof_df])
        LOGGER.info(f"========== fold: {fold} result ==========")
        best_threshold = get_result(_oof_df)
        threshold.append(best_threshold)
        
    # CV result
    LOGGER.info(f"========== CV ==========")
    get_result(oof_df)
    
    # Save OOF result
    oof_df.to_csv(OUTPUT_DIR + f"{config.FILENAME}_oof_df.csv", index=False)

    # Inference
    proba_predictions = inference()
    predictions = np.where(proba_predictions < config.border, 0, 1)

    # submission
    sub["judgement"] = predictions
    sub.to_csv(OUTPUT_DIR + f"./sub_{config.FILENAME}.csv", index=False, header=False)

    # mean threshold
    predictions = np.where(proba_predictions < np.mean(threshold), 0, 1)

    sub["judgement"] = predictions
    sub.to_csv(OUTPUT_DIR + f"./sub_mean_thr_{config.FILENAME}.csv", index=False, header=False)

    #stack = pd.read_csv(DATA_DIR + "sample_submit.csv", header=None)
    sub["judgement"] = proba_predictions
    sub.to_csv(OUTPUT_DIR + f"./stack_{config.FILENAME}.csv", index=False, header=False)

# %%
if __name__ == "__main__":
  main()
# Out:
# ========== fold: 0 training ==========
# Downloading:   0%|          | 0.00/225k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: [1][0/1357] Elapsed 0m 2s (remain 51m 5s) Loss: 0.6718
# Epoch: [1][100/1357] Elapsed 1m 8s (remain 14m 12s) Loss: 0.2067
# Epoch: [1][200/1357] Elapsed 2m 14s (remain 12m 55s) Loss: 0.1525
# Epoch: [1][300/1357] Elapsed 3m 20s (remain 11m 45s) Loss: 0.1406
# Epoch: [1][400/1357] Elapsed 4m 27s (remain 10m 36s) Loss: 0.1300
# Epoch: [1][500/1357] Elapsed 5m 33s (remain 9m 29s) Loss: 0.1199
# Epoch: [1][600/1357] Elapsed 6m 39s (remain 8m 22s) Loss: 0.1114
# Epoch: [1][700/1357] Elapsed 7m 45s (remain 7m 15s) Loss: 0.1047
# Epoch: [1][800/1357] Elapsed 8m 51s (remain 6m 9s) Loss: 0.0979
# Epoch: [1][900/1357] Elapsed 9m 58s (remain 5m 2s) Loss: 0.0959
# Epoch: [1][1000/1357] Elapsed 11m 4s (remain 3m 56s) Loss: 0.0921
# Epoch: [1][1100/1357] Elapsed 12m 10s (remain 2m 49s) Loss: 0.0891
# Epoch: [1][1200/1357] Elapsed 13m 16s (remain 1m 43s) Loss: 0.0868
# Epoch: [1][1300/1357] Elapsed 14m 22s (remain 0m 37s) Loss: 0.0847
# Epoch: [1][1356/1357] Elapsed 14m 59s (remain 0m 0s) Loss: 0.0840
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 48s) Loss: 0.0143
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0645
# EVAL: [200/340] Elapsed 0m 44s (remain 0m 30s) Loss: 0.0614
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0593
# Epoch 1 - avg_train_loss: 0.0840  avg_val_loss: 0.0588  time: 974s
# Epoch 1 - Score: 0.7802149271308698
# Epoch 1 - Save Best Score: 0.7802 Model
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0588
# Epoch: [2][0/1357] Elapsed 0m 0s (remain 18m 23s) Loss: 0.0242
# Epoch: [2][100/1357] Elapsed 1m 6s (remain 13m 52s) Loss: 0.0404
# Epoch: [2][200/1357] Elapsed 2m 13s (remain 12m 45s) Loss: 0.0443
# Epoch: [2][300/1357] Elapsed 3m 19s (remain 11m 39s) Loss: 0.0453
# Epoch: [2][400/1357] Elapsed 4m 25s (remain 10m 32s) Loss: 0.0444
# Epoch: [2][500/1357] Elapsed 5m 31s (remain 9m 26s) Loss: 0.0478
# Epoch: [2][600/1357] Elapsed 6m 37s (remain 8m 20s) Loss: 0.0493
# Epoch: [2][700/1357] Elapsed 7m 43s (remain 7m 14s) Loss: 0.0490
# Epoch: [2][800/1357] Elapsed 8m 50s (remain 6m 7s) Loss: 0.0474
# Epoch: [2][900/1357] Elapsed 9m 56s (remain 5m 1s) Loss: 0.0466
# Epoch: [2][1000/1357] Elapsed 11m 2s (remain 3m 55s) Loss: 0.0464
# Epoch: [2][1100/1357] Elapsed 12m 8s (remain 2m 49s) Loss: 0.0477
# Epoch: [2][1200/1357] Elapsed 13m 14s (remain 1m 43s) Loss: 0.0476
# Epoch: [2][1300/1357] Elapsed 14m 20s (remain 0m 37s) Loss: 0.0468
# Epoch: [2][1356/1357] Elapsed 14m 57s (remain 0m 0s) Loss: 0.0467
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 0s) Loss: 0.0058
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0563
# EVAL: [200/340] Elapsed 0m 43s (remain 0m 30s) Loss: 0.0561
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0531
# Epoch 2 - avg_train_loss: 0.0467  avg_val_loss: 0.0525  time: 972s
# Epoch 2 - Score: 0.8907004830917874
# Epoch 2 - Save Best Score: 0.8907 Model
# EVAL: [339/340] Elapsed 1m 13s (remain 0m 0s) Loss: 0.0525
# Epoch: [3][0/1357] Elapsed 0m 0s (remain 18m 12s) Loss: 0.1866
# Epoch: [3][100/1357] Elapsed 1m 6s (remain 13m 52s) Loss: 0.0279
# Epoch: [3][200/1357] Elapsed 2m 13s (remain 12m 45s) Loss: 0.0403
# Epoch: [3][300/1357] Elapsed 3m 19s (remain 11m 39s) Loss: 0.0429
# Epoch: [3][400/1357] Elapsed 4m 25s (remain 10m 33s) Loss: 0.0433
# Epoch: [3][500/1357] Elapsed 5m 31s (remain 9m 27s) Loss: 0.0424
# Epoch: [3][600/1357] Elapsed 6m 38s (remain 8m 20s) Loss: 0.0415
# Epoch: [3][700/1357] Elapsed 7m 44s (remain 7m 14s) Loss: 0.0419
# Epoch: [3][800/1357] Elapsed 8m 50s (remain 6m 8s) Loss: 0.0413
# Epoch: [3][900/1357] Elapsed 9m 56s (remain 5m 1s) Loss: 0.0398
# Epoch: [3][1000/1357] Elapsed 11m 2s (remain 3m 55s) Loss: 0.0386
# Epoch: [3][1100/1357] Elapsed 12m 8s (remain 2m 49s) Loss: 0.0383
# Epoch: [3][1200/1357] Elapsed 13m 15s (remain 1m 43s) Loss: 0.0373
# Epoch: [3][1300/1357] Elapsed 14m 21s (remain 0m 37s) Loss: 0.0356
# Epoch: [3][1356/1357] Elapsed 14m 58s (remain 0m 0s) Loss: 0.0367
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 1s) Loss: 0.0054
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0431
# EVAL: [200/340] Elapsed 0m 43s (remain 0m 30s) Loss: 0.0503
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0468
# Epoch 3 - avg_train_loss: 0.0367  avg_val_loss: 0.0449  time: 972s
# Epoch 3 - Score: 0.8843432789910797
# EVAL: [339/340] Elapsed 1m 13s (remain 0m 0s) Loss: 0.0449
# ========== fold: 0 result ==========
# Score: 0.89070
# Best threshold : 0.03058
# After optimizing score: 0.87373
# ========== fold: 1 training ==========
# Some weights of the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: [1][0/1357] Elapsed 0m 0s (remain 20m 49s) Loss: 0.7079
# Epoch: [1][100/1357] Elapsed 1m 7s (remain 13m 54s) Loss: 0.2290
# Epoch: [1][200/1357] Elapsed 2m 13s (remain 12m 47s) Loss: 0.1662
# Epoch: [1][300/1357] Elapsed 3m 19s (remain 11m 40s) Loss: 0.1443
# Epoch: [1][400/1357] Elapsed 4m 26s (remain 10m 34s) Loss: 0.1287
# Epoch: [1][500/1357] Elapsed 5m 32s (remain 9m 28s) Loss: 0.1203
# Epoch: [1][600/1357] Elapsed 6m 38s (remain 8m 21s) Loss: 0.1090
# Epoch: [1][700/1357] Elapsed 7m 45s (remain 7m 15s) Loss: 0.0998
# Epoch: [1][800/1357] Elapsed 8m 51s (remain 6m 8s) Loss: 0.0970
# Epoch: [1][900/1357] Elapsed 9m 57s (remain 5m 2s) Loss: 0.0939
# Epoch: [1][1000/1357] Elapsed 11m 4s (remain 3m 56s) Loss: 0.0897
# Epoch: [1][1100/1357] Elapsed 12m 10s (remain 2m 49s) Loss: 0.0869
# Epoch: [1][1200/1357] Elapsed 13m 16s (remain 1m 43s) Loss: 0.0839
# Epoch: [1][1300/1357] Elapsed 14m 23s (remain 0m 37s) Loss: 0.0823
# Epoch: [1][1356/1357] Elapsed 15m 0s (remain 0m 0s) Loss: 0.0808
# EVAL: [0/340] Elapsed 0m 0s (remain 3m 10s) Loss: 0.0095
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0363
# EVAL: [200/340] Elapsed 0m 44s (remain 0m 30s) Loss: 0.0389
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0412
# Epoch 1 - avg_train_loss: 0.0808  avg_val_loss: 0.0427  time: 975s
# Epoch 1 - Score: 0.8837277242185219
# Epoch 1 - Save Best Score: 0.8837 Model
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0427
# Epoch: [2][0/1357] Elapsed 0m 0s (remain 18m 51s) Loss: 0.1167
# Epoch: [2][100/1357] Elapsed 1m 7s (remain 13m 55s) Loss: 0.0347
# Epoch: [2][200/1357] Elapsed 2m 13s (remain 12m 46s) Loss: 0.0394
# Epoch: [2][300/1357] Elapsed 3m 19s (remain 11m 39s) Loss: 0.0385
# Epoch: [2][400/1357] Elapsed 4m 25s (remain 10m 33s) Loss: 0.0383
# Epoch: [2][500/1357] Elapsed 5m 31s (remain 9m 27s) Loss: 0.0369
# Epoch: [2][600/1357] Elapsed 6m 38s (remain 8m 20s) Loss: 0.0379
# Epoch: [2][700/1357] Elapsed 7m 44s (remain 7m 14s) Loss: 0.0388
# Epoch: [2][800/1357] Elapsed 8m 50s (remain 6m 8s) Loss: 0.0398
# Epoch: [2][900/1357] Elapsed 9m 56s (remain 5m 1s) Loss: 0.0385
# Epoch: [2][1000/1357] Elapsed 11m 2s (remain 3m 55s) Loss: 0.0371
# Epoch: [2][1100/1357] Elapsed 12m 9s (remain 2m 49s) Loss: 0.0378
# Epoch: [2][1200/1357] Elapsed 13m 15s (remain 1m 43s) Loss: 0.0370
# Epoch: [2][1300/1357] Elapsed 14m 21s (remain 0m 37s) Loss: 0.0370
# Epoch: [2][1356/1357] Elapsed 14m 58s (remain 0m 0s) Loss: 0.0368
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 22s) Loss: 0.0060
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0282
# EVAL: [200/340] Elapsed 0m 43s (remain 0m 30s) Loss: 0.0283
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0317
# Epoch 2 - avg_train_loss: 0.0368  avg_val_loss: 0.0335  time: 973s
# Epoch 2 - Score: 0.9040645546921698
# Epoch 2 - Save Best Score: 0.9041 Model
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0335
# Epoch: [3][0/1357] Elapsed 0m 0s (remain 18m 49s) Loss: 0.0372
# Epoch: [3][100/1357] Elapsed 1m 6s (remain 13m 52s) Loss: 0.0180
# Epoch: [3][200/1357] Elapsed 2m 13s (remain 12m 45s) Loss: 0.0237
# Epoch: [3][300/1357] Elapsed 3m 19s (remain 11m 39s) Loss: 0.0235
# Epoch: [3][400/1357] Elapsed 4m 25s (remain 10m 32s) Loss: 0.0233
# Epoch: [3][500/1357] Elapsed 5m 31s (remain 9m 26s) Loss: 0.0223
# Epoch: [3][600/1357] Elapsed 6m 37s (remain 8m 20s) Loss: 0.0225
# Epoch: [3][700/1357] Elapsed 7m 43s (remain 7m 13s) Loss: 0.0222
# Epoch: [3][800/1357] Elapsed 8m 49s (remain 6m 7s) Loss: 0.0214
# Epoch: [3][900/1357] Elapsed 9m 56s (remain 5m 1s) Loss: 0.0211
# Epoch: [3][1000/1357] Elapsed 11m 2s (remain 3m 55s) Loss: 0.0220
# Epoch: [3][1100/1357] Elapsed 12m 8s (remain 2m 49s) Loss: 0.0217
# Epoch: [3][1200/1357] Elapsed 13m 14s (remain 1m 43s) Loss: 0.0228
# Epoch: [3][1300/1357] Elapsed 14m 20s (remain 0m 37s) Loss: 0.0225
# Epoch: [3][1356/1357] Elapsed 14m 57s (remain 0m 0s) Loss: 0.0223
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 18s) Loss: 0.0001
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0371
# EVAL: [200/340] Elapsed 0m 43s (remain 0m 30s) Loss: 0.0357
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0399
# Epoch 3 - avg_train_loss: 0.0223  avg_val_loss: 0.0412  time: 972s
# Epoch 3 - Score: 0.9142053445850914
# Epoch 3 - Save Best Score: 0.9142 Model
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0412
# ========== fold: 1 result ==========
# Score: 0.91421
# Best threshold : 0.01721
# After optimizing score: 0.91278
# ========== fold: 2 training ==========
# Some weights of the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: [1][0/1357] Elapsed 0m 0s (remain 20m 6s) Loss: 0.6732
# Epoch: [1][100/1357] Elapsed 1m 6s (remain 13m 52s) Loss: 0.2272
# Epoch: [1][200/1357] Elapsed 2m 13s (remain 12m 44s) Loss: 0.1827
# Epoch: [1][300/1357] Elapsed 3m 19s (remain 11m 38s) Loss: 0.1587
# Epoch: [1][400/1357] Elapsed 4m 25s (remain 10m 32s) Loss: 0.1478
# Epoch: [1][500/1357] Elapsed 5m 31s (remain 9m 26s) Loss: 0.1357
# Epoch: [1][600/1357] Elapsed 6m 37s (remain 8m 19s) Loss: 0.1242
# Epoch: [1][700/1357] Elapsed 7m 43s (remain 7m 13s) Loss: 0.1147
# Epoch: [1][800/1357] Elapsed 8m 49s (remain 6m 7s) Loss: 0.1074
# Epoch: [1][900/1357] Elapsed 9m 55s (remain 5m 1s) Loss: 0.1028
# Epoch: [1][1000/1357] Elapsed 11m 1s (remain 3m 55s) Loss: 0.0963
# Epoch: [1][1100/1357] Elapsed 12m 7s (remain 2m 49s) Loss: 0.0928
# Epoch: [1][1200/1357] Elapsed 13m 13s (remain 1m 43s) Loss: 0.0886
# Epoch: [1][1300/1357] Elapsed 14m 19s (remain 0m 37s) Loss: 0.0844
# Epoch: [1][1356/1357] Elapsed 14m 56s (remain 0m 0s) Loss: 0.0829
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 18s) Loss: 0.0102
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0470
# EVAL: [200/340] Elapsed 0m 43s (remain 0m 30s) Loss: 0.0523
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0532
# Epoch 1 - avg_train_loss: 0.0829  avg_val_loss: 0.0525  time: 971s
# Epoch 1 - Score: 0.8815180038846555
# Epoch 1 - Save Best Score: 0.8815 Model
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0525
# Epoch: [2][0/1357] Elapsed 0m 0s (remain 19m 56s) Loss: 0.0039
# Epoch: [2][100/1357] Elapsed 1m 6s (remain 13m 53s) Loss: 0.0481
# Epoch: [2][200/1357] Elapsed 2m 13s (remain 12m 45s) Loss: 0.0444
# Epoch: [2][300/1357] Elapsed 3m 19s (remain 11m 38s) Loss: 0.0439
# Epoch: [2][400/1357] Elapsed 4m 25s (remain 10m 32s) Loss: 0.0429
# Epoch: [2][500/1357] Elapsed 5m 31s (remain 9m 26s) Loss: 0.0424
# Epoch: [2][600/1357] Elapsed 6m 37s (remain 8m 20s) Loss: 0.0411
# Epoch: [2][700/1357] Elapsed 7m 43s (remain 7m 14s) Loss: 0.0387
# Epoch: [2][800/1357] Elapsed 8m 50s (remain 6m 8s) Loss: 0.0387
# Epoch: [2][900/1357] Elapsed 9m 56s (remain 5m 1s) Loss: 0.0385
# Epoch: [2][1000/1357] Elapsed 11m 2s (remain 3m 55s) Loss: 0.0379
# Epoch: [2][1100/1357] Elapsed 12m 9s (remain 2m 49s) Loss: 0.0379
# Epoch: [2][1200/1357] Elapsed 13m 16s (remain 1m 43s) Loss: 0.0381
# Epoch: [2][1300/1357] Elapsed 14m 22s (remain 0m 37s) Loss: 0.0377
# Epoch: [2][1356/1357] Elapsed 14m 59s (remain 0m 0s) Loss: 0.0379
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 34s) Loss: 0.0008
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0452
# EVAL: [200/340] Elapsed 0m 44s (remain 0m 30s) Loss: 0.0429
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0451
# Epoch 2 - avg_train_loss: 0.0379  avg_val_loss: 0.0445  time: 974s
# Epoch 2 - Score: 0.8278662917838175
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0445
# Epoch: [3][0/1357] Elapsed 0m 0s (remain 19m 30s) Loss: 0.0247
# Epoch: [3][100/1357] Elapsed 1m 7s (remain 13m 56s) Loss: 0.0287
# Epoch: [3][200/1357] Elapsed 2m 13s (remain 12m 48s) Loss: 0.0299
# Epoch: [3][300/1357] Elapsed 3m 20s (remain 11m 41s) Loss: 0.0255
# Epoch: [3][400/1357] Elapsed 4m 26s (remain 10m 35s) Loss: 0.0258
# Epoch: [3][500/1357] Elapsed 5m 32s (remain 9m 28s) Loss: 0.0261
# Epoch: [3][600/1357] Elapsed 6m 39s (remain 8m 22s) Loss: 0.0253
# Epoch: [3][700/1357] Elapsed 7m 45s (remain 7m 15s) Loss: 0.0260
# Epoch: [3][800/1357] Elapsed 8m 51s (remain 6m 9s) Loss: 0.0264
# Epoch: [3][900/1357] Elapsed 9m 58s (remain 5m 2s) Loss: 0.0263
# Epoch: [3][1000/1357] Elapsed 11m 4s (remain 3m 56s) Loss: 0.0264
# Epoch: [3][1100/1357] Elapsed 12m 11s (remain 2m 49s) Loss: 0.0268
# Epoch: [3][1200/1357] Elapsed 13m 17s (remain 1m 43s) Loss: 0.0266
# Epoch: [3][1300/1357] Elapsed 14m 23s (remain 0m 37s) Loss: 0.0268
# Epoch: [3][1356/1357] Elapsed 15m 0s (remain 0m 0s) Loss: 0.0270
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 20s) Loss: 0.0024
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0430
# EVAL: [200/340] Elapsed 0m 44s (remain 0m 30s) Loss: 0.0485
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0487
# Epoch 3 - avg_train_loss: 0.0270  avg_val_loss: 0.0458  time: 975s
# Epoch 3 - Score: 0.8666047663262149
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0458
# ========== fold: 2 result ==========
# Score: 0.88152
# Best threshold : 0.01831
# After optimizing score: 0.89021
# ========== fold: 3 training ==========
# Some weights of the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: [1][0/1357] Elapsed 0m 0s (remain 20m 1s) Loss: 0.7009
# Epoch: [1][100/1357] Elapsed 1m 7s (remain 13m 56s) Loss: 0.2015
# Epoch: [1][200/1357] Elapsed 2m 13s (remain 12m 48s) Loss: 0.1666
# Epoch: [1][300/1357] Elapsed 3m 19s (remain 11m 41s) Loss: 0.1419
# Epoch: [1][400/1357] Elapsed 4m 26s (remain 10m 34s) Loss: 0.1287
# Epoch: [1][500/1357] Elapsed 5m 32s (remain 9m 28s) Loss: 0.1191
# Epoch: [1][600/1357] Elapsed 6m 38s (remain 8m 21s) Loss: 0.1099
# Epoch: [1][700/1357] Elapsed 7m 45s (remain 7m 15s) Loss: 0.1025
# Epoch: [1][800/1357] Elapsed 8m 51s (remain 6m 8s) Loss: 0.0968
# Epoch: [1][900/1357] Elapsed 9m 57s (remain 5m 2s) Loss: 0.0920
# Epoch: [1][1000/1357] Elapsed 11m 3s (remain 3m 56s) Loss: 0.0874
# Epoch: [1][1100/1357] Elapsed 12m 10s (remain 2m 49s) Loss: 0.0849
# Epoch: [1][1200/1357] Elapsed 13m 16s (remain 1m 43s) Loss: 0.0816
# Epoch: [1][1300/1357] Elapsed 14m 22s (remain 0m 37s) Loss: 0.0798
# Epoch: [1][1356/1357] Elapsed 14m 59s (remain 0m 0s) Loss: 0.0793
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 26s) Loss: 0.0053
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0617
# EVAL: [200/340] Elapsed 0m 43s (remain 0m 30s) Loss: 0.0547
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0546
# Epoch 1 - avg_train_loss: 0.0793  avg_val_loss: 0.0549  time: 974s
# Epoch 1 - Score: 0.8776896942242356
# Epoch 1 - Save Best Score: 0.8777 Model
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0549
# Epoch: [2][0/1357] Elapsed 0m 0s (remain 19m 57s) Loss: 0.0705
# Epoch: [2][100/1357] Elapsed 1m 7s (remain 13m 55s) Loss: 0.0275
# Epoch: [2][200/1357] Elapsed 2m 13s (remain 12m 47s) Loss: 0.0287
# Epoch: [2][300/1357] Elapsed 3m 19s (remain 11m 40s) Loss: 0.0280
# Epoch: [2][400/1357] Elapsed 4m 25s (remain 10m 33s) Loss: 0.0298
# Epoch: [2][500/1357] Elapsed 5m 32s (remain 9m 27s) Loss: 0.0298
# Epoch: [2][600/1357] Elapsed 6m 38s (remain 8m 21s) Loss: 0.0304
# Epoch: [2][700/1357] Elapsed 7m 44s (remain 7m 14s) Loss: 0.0301
# Epoch: [2][800/1357] Elapsed 8m 50s (remain 6m 8s) Loss: 0.0300
# Epoch: [2][900/1357] Elapsed 9m 57s (remain 5m 2s) Loss: 0.0301
# Epoch: [2][1000/1357] Elapsed 11m 3s (remain 3m 55s) Loss: 0.0304
# Epoch: [2][1100/1357] Elapsed 12m 9s (remain 2m 49s) Loss: 0.0307
# Epoch: [2][1200/1357] Elapsed 13m 15s (remain 1m 43s) Loss: 0.0322
# Epoch: [2][1300/1357] Elapsed 14m 21s (remain 0m 37s) Loss: 0.0329
# Epoch: [2][1356/1357] Elapsed 14m 58s (remain 0m 0s) Loss: 0.0332
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 30s) Loss: 0.0005
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0461
# EVAL: [200/340] Elapsed 0m 43s (remain 0m 30s) Loss: 0.0396
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0393
# Epoch 2 - avg_train_loss: 0.0332  avg_val_loss: 0.0400  time: 973s
# Epoch 2 - Score: 0.8984794962371373
# Epoch 2 - Save Best Score: 0.8985 Model
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0400
# Epoch: [3][0/1357] Elapsed 0m 0s (remain 19m 42s) Loss: 0.0011
# Epoch: [3][100/1357] Elapsed 1m 7s (remain 13m 53s) Loss: 0.0174
# Epoch: [3][200/1357] Elapsed 2m 13s (remain 12m 46s) Loss: 0.0191
# Epoch: [3][300/1357] Elapsed 3m 19s (remain 11m 39s) Loss: 0.0196
# Epoch: [3][400/1357] Elapsed 4m 25s (remain 10m 32s) Loss: 0.0209
# Epoch: [3][500/1357] Elapsed 5m 31s (remain 9m 26s) Loss: 0.0204
# Epoch: [3][600/1357] Elapsed 6m 37s (remain 8m 20s) Loss: 0.0245
# Epoch: [3][700/1357] Elapsed 7m 43s (remain 7m 14s) Loss: 0.0237
# Epoch: [3][800/1357] Elapsed 8m 50s (remain 6m 7s) Loss: 0.0237
# Epoch: [3][900/1357] Elapsed 9m 56s (remain 5m 1s) Loss: 0.0241
# Epoch: [3][1000/1357] Elapsed 11m 2s (remain 3m 55s) Loss: 0.0234
# Epoch: [3][1100/1357] Elapsed 12m 8s (remain 2m 49s) Loss: 0.0237
# Epoch: [3][1200/1357] Elapsed 13m 14s (remain 1m 43s) Loss: 0.0230
# Epoch: [3][1300/1357] Elapsed 14m 20s (remain 0m 37s) Loss: 0.0237
# Epoch: [3][1356/1357] Elapsed 14m 57s (remain 0m 0s) Loss: 0.0236
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 23s) Loss: 0.0003
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0514
# EVAL: [200/340] Elapsed 0m 43s (remain 0m 30s) Loss: 0.0445
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0457
# Epoch 3 - avg_train_loss: 0.0236  avg_val_loss: 0.0455  time: 972s
# Epoch 3 - Score: 0.8645978076269879
# EVAL: [339/340] Elapsed 1m 13s (remain 0m 0s) Loss: 0.0455
# ========== fold: 3 result ==========
# Score: 0.89848
# Best threshold : 0.00811
# After optimizing score: 0.92029
# ========== fold: 4 training ==========
# Some weights of the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: [1][0/1357] Elapsed 0m 0s (remain 19m 51s) Loss: 0.7529
# Epoch: [1][100/1357] Elapsed 1m 7s (remain 13m 53s) Loss: 0.2392
# Epoch: [1][200/1357] Elapsed 2m 13s (remain 12m 46s) Loss: 0.1781
# Epoch: [1][300/1357] Elapsed 3m 19s (remain 11m 40s) Loss: 0.1562
# Epoch: [1][400/1357] Elapsed 4m 25s (remain 10m 33s) Loss: 0.1406
# Epoch: [1][500/1357] Elapsed 5m 31s (remain 9m 27s) Loss: 0.1256
# Epoch: [1][600/1357] Elapsed 6m 38s (remain 8m 20s) Loss: 0.1182
# Epoch: [1][700/1357] Elapsed 7m 44s (remain 7m 14s) Loss: 0.1122
# Epoch: [1][800/1357] Elapsed 8m 50s (remain 6m 8s) Loss: 0.1052
# Epoch: [1][900/1357] Elapsed 9m 56s (remain 5m 2s) Loss: 0.1010
# Epoch: [1][1000/1357] Elapsed 11m 3s (remain 3m 55s) Loss: 0.0976
# Epoch: [1][1100/1357] Elapsed 12m 9s (remain 2m 49s) Loss: 0.0942
# Epoch: [1][1200/1357] Elapsed 13m 15s (remain 1m 43s) Loss: 0.0890
# Epoch: [1][1300/1357] Elapsed 14m 21s (remain 0m 37s) Loss: 0.0863
# Epoch: [1][1356/1357] Elapsed 14m 58s (remain 0m 0s) Loss: 0.0850
# EVAL: [0/340] Elapsed 0m 0s (remain 3m 13s) Loss: 0.1007
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0265
# EVAL: [200/340] Elapsed 0m 44s (remain 0m 30s) Loss: 0.0316
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0352
# Epoch 1 - avg_train_loss: 0.0850  avg_val_loss: 0.0338  time: 973s
# Epoch 1 - Score: 0.9252237221295313
# Epoch 1 - Save Best Score: 0.9252 Model
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0338
# Epoch: [2][0/1357] Elapsed 0m 0s (remain 19m 22s) Loss: 0.0061
# Epoch: [2][100/1357] Elapsed 1m 7s (remain 13m 53s) Loss: 0.0336
# Epoch: [2][200/1357] Elapsed 2m 13s (remain 12m 45s) Loss: 0.0366
# Epoch: [2][300/1357] Elapsed 3m 19s (remain 11m 39s) Loss: 0.0378
# Epoch: [2][400/1357] Elapsed 4m 25s (remain 10m 33s) Loss: 0.0393
# Epoch: [2][500/1357] Elapsed 5m 31s (remain 9m 26s) Loss: 0.0385
# Epoch: [2][600/1357] Elapsed 6m 37s (remain 8m 20s) Loss: 0.0384
# Epoch: [2][700/1357] Elapsed 7m 44s (remain 7m 14s) Loss: 0.0377
# Epoch: [2][800/1357] Elapsed 8m 50s (remain 6m 8s) Loss: 0.0375
# Epoch: [2][900/1357] Elapsed 9m 56s (remain 5m 1s) Loss: 0.0373
# Epoch: [2][1000/1357] Elapsed 11m 2s (remain 3m 55s) Loss: 0.0371
# Epoch: [2][1100/1357] Elapsed 12m 8s (remain 2m 49s) Loss: 0.0378
# Epoch: [2][1200/1357] Elapsed 13m 15s (remain 1m 43s) Loss: 0.0373
# Epoch: [2][1300/1357] Elapsed 14m 21s (remain 0m 37s) Loss: 0.0373
# Epoch: [2][1356/1357] Elapsed 14m 58s (remain 0m 0s) Loss: 0.0374
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 30s) Loss: 0.1718
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0334
# EVAL: [200/340] Elapsed 0m 43s (remain 0m 30s) Loss: 0.0370
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0392
# Epoch 2 - avg_train_loss: 0.0374  avg_val_loss: 0.0377  time: 972s
# Epoch 2 - Score: 0.9132420091324202
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0377
# Epoch: [3][0/1357] Elapsed 0m 0s (remain 19m 19s) Loss: 0.0254
# Epoch: [3][100/1357] Elapsed 1m 7s (remain 13m 54s) Loss: 0.0246
# Epoch: [3][200/1357] Elapsed 2m 13s (remain 12m 46s) Loss: 0.0222
# Epoch: [3][300/1357] Elapsed 3m 19s (remain 11m 39s) Loss: 0.0206
# Epoch: [3][400/1357] Elapsed 4m 25s (remain 10m 33s) Loss: 0.0224
# Epoch: [3][500/1357] Elapsed 5m 31s (remain 9m 26s) Loss: 0.0207
# Epoch: [3][600/1357] Elapsed 6m 37s (remain 8m 20s) Loss: 0.0214
# Epoch: [3][700/1357] Elapsed 7m 44s (remain 7m 14s) Loss: 0.0213
# Epoch: [3][800/1357] Elapsed 8m 50s (remain 6m 8s) Loss: 0.0217
# Epoch: [3][900/1357] Elapsed 9m 56s (remain 5m 1s) Loss: 0.0212
# Epoch: [3][1000/1357] Elapsed 11m 2s (remain 3m 55s) Loss: 0.0222
# Epoch: [3][1100/1357] Elapsed 12m 8s (remain 2m 49s) Loss: 0.0223
# Epoch: [3][1200/1357] Elapsed 13m 15s (remain 1m 43s) Loss: 0.0224
# Epoch: [3][1300/1357] Elapsed 14m 21s (remain 0m 37s) Loss: 0.0231
# Epoch: [3][1356/1357] Elapsed 14m 58s (remain 0m 0s) Loss: 0.0232
# EVAL: [0/340] Elapsed 0m 0s (remain 2m 32s) Loss: 0.0612
# EVAL: [100/340] Elapsed 0m 22s (remain 0m 52s) Loss: 0.0280
# EVAL: [200/340] Elapsed 0m 44s (remain 0m 30s) Loss: 0.0354
# EVAL: [300/340] Elapsed 1m 5s (remain 0m 8s) Loss: 0.0428
# Epoch 3 - avg_train_loss: 0.0232  avg_val_loss: 0.0397  time: 973s
# Epoch 3 - Score: 0.8382952052648073
# EVAL: [339/340] Elapsed 1m 14s (remain 0m 0s) Loss: 0.0397
# ========== fold: 4 result ==========
# Score: 0.92522
# Best threshold : 0.04868
# After optimizing score: 0.92379
# ========== CV ==========
# Score: 0.90189
# Best threshold : 0.00922
# After optimizing score: 0.90713
# ========== model: bioelectra-base fold: 0 inference ==========
# Some weights of the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/2553 [00:00<?, ?it/s]
# ========== model: bioelectra-base fold: 1 inference ==========
# Some weights of the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/2553 [00:00<?, ?it/s]
# ========== model: bioelectra-base fold: 2 inference ==========
# Some weights of the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/2553 [00:00<?, ?it/s]
# ========== model: bioelectra-base fold: 3 inference ==========
# Some weights of the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/2553 [00:00<?, ?it/s]
# ========== model: bioelectra-base fold: 4 inference ==========
# Some weights of the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at kamalkraj/bioelectra-base-discriminator-pubmed and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/2553 [00:00<?, ?it/s]
